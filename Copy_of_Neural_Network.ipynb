# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Models/scores.csv')

# %%
df.head()
# Out:
#    District    Borough  Average District Score (SAT Math)  \
# 0         1  Manhattan                         505.000000
# 1         2  Manhattan                         460.666667
# 2         3  Manhattan                         382.500000
# 3         4  Manhattan                         364.500000
# 4         5  Manhattan                         549.500000
#
#    Average District Score (SAT Reading)  Average District Score (SAT Writing)  \
# 0                            474.000000                            468.666670
# 1                            446.979167                            440.520833
# 2                            386.500000                            376.500000
# 3                            374.000000                            368.500000
# 4                            527.500000                            518.000000
#
#    Breakfast_ADP  Lunch_ADP  After_School_Snacks_ADP  After_School_Supper_ADP
# 0           3139       6888                     1710                     1183
# 1           8376      24952                     3003                     1693
# 2           6119      11943                     2115                     1043
# 3           3844       9231                     2934                     1093
# 4           4978       9666                     4157                     1467

# %%
import tensorflow as tf
import keras
from keras import layers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import BatchNormalization
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.layers import Flatten
from sklearn.model_selection import train_test_split

Xinput = input("Enter desired average ADP (Breakfast, Lunch, Supper, Snacks)")
Yinput = input("Enter desired average SAT (Math, Reading, Writing)")

if Xinput == "Breakfast":
  X = df['Breakfast_ADP']
if Xinput == "Lunch":
  X = df['Lunch_ADP']
if Xinput == "Supper":
  X = df['After_School_Supper_ADP']
if Xinput == "Snacks":
  X = df['After_School_Snacks_ADP']

if Yinput == "Math":
  y = df['Average District Score (SAT Math)']
if Yinput == "Reading":
  y = df['Average District Score (SAT Reading)']
if Yinput == "Writing":
  y = df['Average District Score (SAT Writing)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape)
print(y_train.shape)

"""
Things you can change:
1. Number of nodes in each layer
2. Number of layers
3. Types of layers
4. Number of epochs
5. Activation
"""
model = tf.keras.models.Sequential([
    Dense(512, activation=tf.nn.relu),
    Dense(256, activation=tf.nn.relu),
    Dropout(0.5),
    Dense(64, activation=tf.nn.relu),
    Dense(32, activation=tf.nn.relu),
    Dense(1)
])
#model.compile(optimizer="adam", loss="mse")
model.compile(optimizer="adam", loss="mse", metrics=["mse"])
model.fit(X_train, y_train, epochs=75, validation_data=(X_test, y_test))

predictions = model(X_train).numpy()
predictions
# Out:
# Enter desired average ADP (Breakfast, Lunch, Supper, Snacks)Breakfast
# Enter desired average SAT (Math, Reading, Writing)Math
# (25,)
# (25,)
# Epoch 1/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 176943.8125 - mse: 176943.8125 - val_loss: 43177.4609 - val_mse: 43177.4609
# Epoch 2/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 39666.9805 - mse: 39666.9805 - val_loss: 142834.9531 - val_mse: 142834.9531
# Epoch 3/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 122479.4219 - mse: 122479.4219 - val_loss: 85143.8203 - val_mse: 85143.8203
# Epoch 4/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 57655.5391 - mse: 57655.5391 - val_loss: 32225.9844 - val_mse: 32225.9844
# Epoch 5/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss:
75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 24805.9824 - mse: 24805.9824 - val_loss: 28960.8418 - val_mse: 28960.8418
# Epoch 57/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 25940.4668 - mse: 25940.4668 - val_loss: 30262.9961 - val_mse: 30262.9961
# Epoch 58/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 26582.9551 - mse: 26582.9551 - val_loss: 30395.2070 - val_mse: 30395.2070
# Epoch 59/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 29209.5352 - mse: 29209.5352 - val_loss: 29946.4473 - val_mse: 29946.4473
# Epoch 60/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 21686.2832 - mse: 21686.2832 - val_loss: 28782.1914 - val_mse: 28782.1914
# Epoch 61/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 27663.5820 - mse: 27663.5820 - val_loss: 28109.2031 - val_mse: 28109.2031
# Epoch 62/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 25127.1816 - mse: 25127.1816 - val_loss: 26941.7637 - val_mse: 26941.7637
# Epoch 63/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 27471.7051 - mse: 27471.7051 - val_loss: 25756.4980 - val_mse: 25756.4980
# Epoch 64/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 34271.3555 - mse: 34271.3555 - val_loss: 25721.7207 - val_mse: 25721.7207
# Epoch 65/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 20874.6953 - mse: 20874.6953 - val_loss: 25562.4941 - val_mse: 25562.4941
# Epoch 66/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 22138.7930 - mse: 22138.7930 - val_loss: 24961.9375 - val_mse: 24961.9375
# Epoch 67/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 22949.5977 - mse: 22949.5977 - val_loss: 24310.2559 - val_mse: 24310.2559
# Epoch 68/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 23203.4941 - mse: 23203.4941 - val_loss: 23903.3652 - val_mse: 23903.3652
# Epoch 69/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 23322.9004 - mse: 23322.9004 - val_loss: 23361.7871 - val_mse: 23361.7871
# Epoch 70/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 32135.6973 - mse: 32135.6973 - val_loss: 22810.9844 - val_mse: 22810.9844
# Epoch 71/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 25927.3477 - mse: 25927.3477 - val_loss: 22492.1250 - val_mse: 22492.1250
# Epoch 72/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 30124.1484 - mse: 30124.1484 - val_loss: 23503.3223 - val_mse: 23503.3223
# Epoch 73/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 27508.7949 - mse: 27508.7949 - val_loss: 24495.7637 - val_mse: 24495.7637
# Epoch 74/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 25529.4707 - mse: 25529.4707 - val_loss: 25055.5156 - val_mse: 25055.5156
# Epoch 75/75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 25692.7695 - mse: 25692.7695 - val_loss: 25506.4824 - val_mse: 25506.4824
# array([[364.30685 ],
#        [278.4037  ],
#        [261.3513  ],
#        [165.40468 ],
#        [255.92357 ],
#        [118.991295],
#        [358.10992 ],
#        [415.33582 ],
#        [265.1977  ],
#        [212.8865  ],
#        [139.67642 ],
#        [355.3319  ],
#        [164.42168 ],
#        [263.65915 ],
#        [208.99733 ],
#        [379.09418 ],
#        [435.5509  ],
#        [303.961   ],
#        [286.43845 ],
#        [353.70782 ],
#        [275.41202 ],
#        [134.2915  ],
#        [467.0061  ],
#        [293.6184  ],
#        [262.84717 ]], dtype=float32)

# %%
y_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
